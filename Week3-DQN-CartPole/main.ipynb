# %%
# Install dependencies from pyproject.toml (works on Google Colab)
# %pip install -q -e .

# %%
config_content = """
CartPole-v1:
  policy: "MlpPolicy"
  n_timesteps: !!float 1e5
  buffer_size: 20000
  learning_starts: 1000
  target_update_interval: 250
  exploration_fraction: 0.2
  exploration_final_eps: 0.06
  learning_rate: !!float 1e-3
  batch_size: 64
  train_freq: 32
  gradient_steps: 16
  gamma: 0.99
  optimize_memory_usage: False
""".strip()

with open("dqn.yaml", "w") as f:
    f.write(config_content)

# %%
# !python -m rl_zoo3.train --algo dqn --env CartPole-v1 -f logs/ -c dqn.yaml --log-interval 1000 --seed 42
# Out:
# 2025-11-09 19:24:40.667075: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762716280.688342    5382 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762716280.694808    5382 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762716280.711960    5382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python -m rl_zoo3.record_video \
    --algo dqn \
    --env CartPole-v1 \
    --folder logs/ \
    -n 500 \
    --deterministic \
    --load-best
# Out:
# 2025-11-09 19:18:25.426689: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762715905.450396    3805 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762715905.457432    3805 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762715905.474539    3805 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from IPython.display import Video

Video("logs/dqn/CartPole-v1_1/videos/best-model-dqn-CartPole-v1-step-0-to-step-500.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
